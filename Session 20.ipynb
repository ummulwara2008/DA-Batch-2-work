# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
 dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
df = pd.read_csv('retail supermarket.csv')
df  # Data Frame
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.shape[0]
# Out:
# 9994

# %%
df.shape[1]
# Out:
# 13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.tail(15)
# Out:
#            Ship Mode      Segment        Country          City       State  \
# 9979  Standard Class  Home Office  United States   Los Angeles  California
# 9980    Second Class     Consumer  United States     Lafayette   Louisiana
# 9981     First Class     Consumer  United States     Fairfield        Ohio
# 9982  Standard Class     Consumer  United States  Grand Rapids    Michigan
# 9983  Standard Class     Consumer  United States  Grand Rapids    Michigan
# 9984  Standard Class     Consumer  United States    Long Beach    New York
# 9985  Standard Class     Consumer  United States    Long Beach    New York
# 9986  Standard Class     Consumer  United States   Los Angeles  California
# 9987  Standard Class    Corporate  United States        Athens     Georgia
# 9988  Standard Class    Corporate  United States        Athens     Georgia
# 9989    Second Class     Consumer  United States         Miami     Florida
# ...

# %%
df  #.loc(int based indexing)  Syntax: df.loc[rox_label,column_index]
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.loc[2]
# Out:
# Ship Mode          Second Class
# Segment               Corporate
# Country           United States
# City                Los Angeles
# State                California
# Postal Code               90036
# Region                     West
# Category        Office Supplies
# Sub-Category             Labels
# Sales                     14.62
# Quantity                      2
# Discount                    0.0
# Profit                   6.8714
# Name: 2, dtype: object

# %%
df.loc[2,'Postal Code']
# Out:
# 90036

# %%
iloc  # Integer based Synatx: df.iloc[row_index,column_index]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 iloc
#
# NameError: name 'iloc' is not defined

# %%
df.iloc[2]
# Out:
# Ship Mode          Second Class
# Segment               Corporate
# Country           United States
# City                Los Angeles
# State                California
# Postal Code               90036
# Region                     West
# Category        Office Supplies
# Sub-Category             Labels
# Sales                     14.62
# Quantity                      2
# Discount                    0.0
# Profit                   6.8714
# Name: 2, dtype: object

# %%
df.loc[2,5]  # Error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 5
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df.loc[2,5]
#
# ...

# %%
df.iloc[2,5]
# Out:
# 90036

# %%
df.loc[2:10]
# Out:
#          Ship Mode    Segment        Country             City       State  \
# 2     Second Class  Corporate  United States      Los Angeles  California
# 3   Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4   Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5   Standard Class   Consumer  United States      Los Angeles  California
# 6   Standard Class   Consumer  United States      Los Angeles  California
# 7   Standard Class   Consumer  United States      Los Angeles  California
# 8   Standard Class   Consumer  United States      Los Angeles  California
# 9   Standard Class   Consumer  United States      Los Angeles  California
# 10  Standard Class   Consumer  United States      Los Angeles  California
#
#     Postal Code Region         Category Sub-Category      Sales  Quantity  \
# 2         90036   West  Office Supplies       Labels    14.6200         2
# 3         33311  South        Furniture       Tables   957.5775         5
# ...

# %%
df.iloc[2:10]
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
# ...

# %%
df.iloc[2:10,7]
# Out:
# 2    Office Supplies
# 3          Furniture
# 4    Office Supplies
# 5          Furniture
# 6    Office Supplies
# 7         Technology
# 8    Office Supplies
# 9    Office Supplies
# Name: Category, dtype: object

# %%
df.loc[2:10,7]  # Error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 7
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df.loc[2:10,7]
#
# ...

# %%
df.loc[2:8,'Region']
# Out:
# 2     West
# 3    South
# 4    South
# 5     West
# 6     West
# 7     West
# 8     West
# Name: Region, dtype: object

# %%
df1=pd.read_csv('retail supermarket.csv',index_col=1)   # Removes Column
df1
# Out:
#                 Ship Mode        Country             City       State  \
# Segment
# Consumer     Second Class  United States        Henderson    Kentucky
# Consumer     Second Class  United States        Henderson    Kentucky
# Corporate    Second Class  United States      Los Angeles  California
# Consumer   Standard Class  United States  Fort Lauderdale     Florida
# Consumer   Standard Class  United States  Fort Lauderdale     Florida
# ...                   ...            ...              ...         ...
# Consumer     Second Class  United States            Miami     Florida
# Consumer   Standard Class  United States       Costa Mesa  California
# Consumer   Standard Class  United States       Costa Mesa  California
# Consumer   Standard Class  United States       Costa Mesa  California
# Consumer     Second Class  United States      Westminster  California
#
#            Postal Code Region         Category Sub-Category     Sales  \
# Segment
# ...

# %%
df1.loc['Consumer']
# Out:
#                Ship Mode        Country             City       State  \
# Segment
# Consumer    Second Class  United States        Henderson    Kentucky
# Consumer    Second Class  United States        Henderson    Kentucky
# Consumer  Standard Class  United States  Fort Lauderdale     Florida
# Consumer  Standard Class  United States  Fort Lauderdale     Florida
# Consumer  Standard Class  United States      Los Angeles  California
# ...                  ...            ...              ...         ...
# Consumer    Second Class  United States            Miami     Florida
# Consumer  Standard Class  United States       Costa Mesa  California
# Consumer  Standard Class  United States       Costa Mesa  California
# Consumer  Standard Class  United States       Costa Mesa  California
# Consumer    Second Class  United States      Westminster  California
#
#           Postal Code Region         Category Sub-Category     Sales  \
# Segment
# ...

# %%
df1.loc['Consumer',:'Quantity']
# Out:
#                Ship Mode        Country             City       State  \
# Segment
# Consumer    Second Class  United States        Henderson    Kentucky
# Consumer    Second Class  United States        Henderson    Kentucky
# Consumer  Standard Class  United States  Fort Lauderdale     Florida
# Consumer  Standard Class  United States  Fort Lauderdale     Florida
# Consumer  Standard Class  United States      Los Angeles  California
# ...                  ...            ...              ...         ...
# Consumer    Second Class  United States            Miami     Florida
# Consumer  Standard Class  United States       Costa Mesa  California
# Consumer  Standard Class  United States       Costa Mesa  California
# Consumer  Standard Class  United States       Costa Mesa  California
# Consumer    Second Class  United States      Westminster  California
#
#           Postal Code Region         Category Sub-Category     Sales  Quantity
# Segment
# ...

# %%
df.iloc[2,10]   # Takes as row and column
# Out:
# 2

# %%
df.iloc[[2,10]]  # List
# Out:
#          Ship Mode    Segment        Country         City       State  \
# 2     Second Class  Corporate  United States  Los Angeles  California
# 10  Standard Class   Consumer  United States  Los Angeles  California
#
#     Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 2         90036   West  Office Supplies       Labels    14.620         2
# 10        90032   West        Furniture       Tables  1706.184         9
#
#     Discount   Profit
# 2        0.0   6.8714
# 10       0.2  85.3092

# %%
df.iloc[[1,5,10,15]]  # Shows the required rows
# Out:
#          Ship Mode      Segment        Country         City       State  \
# 1     Second Class     Consumer  United States    Henderson    Kentucky
# 5   Standard Class     Consumer  United States  Los Angeles  California
# 10  Standard Class     Consumer  United States  Los Angeles  California
# 15  Standard Class  Home Office  United States   Fort Worth       Texas
#
#     Postal Code   Region         Category Sub-Category     Sales  Quantity  \
# 1         42420    South        Furniture       Chairs   731.940         3
# 5         90032     West        Furniture  Furnishings    48.860         7
# 10        90032     West        Furniture       Tables  1706.184         9
# 15        76106  Central  Office Supplies      Binders     2.544         3
#
#     Discount    Profit
# 1        0.0  219.5820
# 5        0.0   14.1694
# 10       0.2   85.3092
# 15       0.8   -3.8160

# %%
df.loc[[2:10]],['Segment','Category']  3 Error
# Out:
#   Cell In[65], line 1
#     df.loc[[2:10]],['Segment','Category']
#              ^
# SyntaxError: invalid syntax

# %%
df.iloc[[1,3]],[[3,7]]
# Out:
# (        Ship Mode   Segment        Country             City     State  \
#  1    Second Class  Consumer  United States        Henderson  Kentucky
#  3  Standard Class  Consumer  United States  Fort Lauderdale   Florida
#
#     Postal Code Region   Category Sub-Category     Sales  Quantity  Discount  \
#  1        42420  South  Furniture       Chairs  731.9400         3      0.00
#  3        33311  South  Furniture       Tables  957.5775         5      0.45
#
#      Profit
#  1  219.582
#  3 -383.031  ,
#  [[3, 7]])

# %%
df['City']
# Out:
# 0             Henderson
# 1             Henderson
# 2           Los Angeles
# 3       Fort Lauderdale
# 4       Fort Lauderdale
#              ...
# 9989              Miami
# 9990         Costa Mesa
# 9991         Costa Mesa
# 9992         Costa Mesa
# 9993        Westminster
# Name: City, Length: 9994, dtype: object

# %%
#pd.options.display.max_rows= None    # Removes Ellipsis

# %%
df['City']
# Out:
# 0             Henderson
# 1             Henderson
# 2           Los Angeles
# 3       Fort Lauderdale
# 4       Fort Lauderdale
#              ...
# 9989              Miami
# 9990         Costa Mesa
# 9991         Costa Mesa
# 9992         Costa Mesa
# 9993        Westminster
# Name: City, Length: 9994, dtype: object

# %%
df[['Country','Postal Code','Category']]
# Out:
#             Country  Postal Code         Category
# 0     United States        42420        Furniture
# 1     United States        42420        Furniture
# 2     United States        90036  Office Supplies
# 3     United States        33311        Furniture
# 4     United States        33311  Office Supplies
# ...             ...          ...              ...
# 9989  United States        33180        Furniture
# 9990  United States        92627        Furniture
# 9991  United States        92627       Technology
# 9992  United States        92627  Office Supplies
# 9993  United States        92683  Office Supplies
#
# [9994 rows x 3 columns]

# %%
df[['Country','Postal Code','Category']].head(6)
# Out:
#          Country  Postal Code         Category
# 0  United States        42420        Furniture
# 1  United States        42420        Furniture
# 2  United States        90036  Office Supplies
# 3  United States        33311        Furniture
# 4  United States        33311  Office Supplies
# 5  United States        90032        Furniture

# %%
df.drop('Postal Code')   # Error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df.drop('Postal Code')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df.drop('Postal Code',axis = 1)
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.drop('Postal Code',axis = 1,inplace = True)   # Removes a desired column   1= axis of column and 0= axis row

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.drop(9993,inplace = True)   # Removes Row

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.drop(9990,inplace = True)

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9988  Standard Class  Corporate  United States           Athens     Georgia
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df2 = pd.read_csv('retail supermarket.csv',header=0)
df2
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df3 = pd.read_csv('retail supermarket.csv',header=1)
df3
# Out:
#         Second Class   Consumer  United States        Henderson    Kentucky  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class  Corporate  United States      Los Angeles  California
# 2     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States      Los Angeles  California
# ...              ...        ...            ...              ...         ...
# 9988    Second Class   Consumer  United States            Miami     Florida
# 9989  Standard Class   Consumer  United States       Costa Mesa  California
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # LOGICAL OPERATORS IN PANDAS:

# %%
# * & (and)
# * | (or)
# *  ~ (not)      tilde

# %%
df['State'] == 'Florida'
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 9988    False
# 9989     True
# 9991    False
# 9992    False
# 9993    False
# Name: State, Length: 9993, dtype: bool

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df[(df['City']=='Florida')]
# Out:
# Empty DataFrame
# Columns: [Ship Mode, Segment, Country, City, State, Region, Category, Sub-Category, Sales, Quantity, Discount, Profit]
# Index: []

# %%
df[(df['State'] == 'Florida')& ~ (df['Category'] == "Technology")]
# Out:
#            Ship Mode      Segment        Country              City    State  \
# 3     Standard Class     Consumer  United States   Fort Lauderdale  Florida
# 4     Standard Class     Consumer  United States   Fort Lauderdale  Florida
# 43    Standard Class    Corporate  United States         Melbourne  Florida
# 231   Standard Class  Home Office  United States             Tampa  Florida
# 232   Standard Class  Home Office  United States             Tampa  Florida
# ...              ...          ...            ...               ...      ...
# 9818  Standard Class    Corporate  United States  Saint Petersburg  Florida
# 9819  Standard Class    Corporate  United States  Saint Petersburg  Florida
# 9820  Standard Class    Corporate  United States  Saint Petersburg  Florida
# 9821  Standard Class    Corporate  United States  Saint Petersburg  Florida
# 9989    Second Class     Consumer  United States             Miami  Florida
#
# ...

# %%
df = pd.DataFrame([[1,2],[3,4],[7,9]],
                    index=['Cobra','clock','vipers'],
                     columns=['max_speed','sandwatch',])
df
# Out:
#         max_speed  sandwatch
# Cobra           1          2
# clock           3          4
# vipers          7          9
