# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
df = pd.read_csv('compensation data.csv')
df   # Data Frame
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df.shape   # Shape of the list
# Out:
# (25973, 6)

# %%
df.shape[1]
# Out:
# 6

# %%
df.shape[0]
# Out:
# 25973

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25973 entries, 0 to 25972
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   experience_coding  25973 non-null  float64
#  1   python_user        25973 non-null  bool
#  2   r_user             25973 non-null  bool
#  3   sql_user           25973 non-null  bool
#  4   most_used          16835 non-null  object
#  5   compensation       25973 non-null  int64
# dtypes: bool(3), float64(1), int64(1), object(1)
# memory usage: 685.0+ KB

# %%
df.dtypes
# Out:
# experience_coding    float64
# python_user             bool
# r_user                  bool
# sql_user                bool
# most_used             object
# compensation           int64
# dtype: object

# %%
df.head()
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
#
#    compensation
# 0        124267
# 1        236889
# 2         74321
# 3         62593
# 4         36288

# %%
df.head(7)
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
# 5                1.0         True   False     False       PyTorch
# 6                1.8        False   False     False           NaN
#
#    compensation
# 0        124267
# 1        236889
# 2         74321
# 3         62593
# 4         36288
# 5         61302
# 6         68984

# %%
df.tail()
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 25968         15800
# 25969         62456
# 25970           923
# 25971         60609
# 25972           493

# %%
df.tail(6)
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 25967                6.1         True   False      True  Scikit-learn
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 25967         80090
# 25968         15800
# 25969         62456
# 25970           923
# 25971         60609
# 25972           493

# %%
# .loc(int based indexing)  Syntax: df.loc[rox_label,column_index]

# %%
df.loc[3]
# Out:
# experience_coding      2.7
# python_user          False
# r_user               False
# sql_user              True
# most_used              NaN
# compensation         62593
# Name: 3, dtype: object

# %%
df.loc[2,'r_user']
# Out:
# False

# %%
#  .iloc   Integer based Synatx: df.iloc[row_index,column_index]

# %%
df.iloc[3]
# Out:
# experience_coding      2.7
# python_user          False
# r_user               False
# sql_user              True
# most_used              NaN
# compensation         62593
# Name: 3, dtype: object

# %%
df.iloc[2,5]   # row,column
# Out:
# 74321

# %%
df.loc[2:8]   # indexing
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
# 5                1.0         True   False     False       PyTorch
# 6                1.8        False   False     False           NaN
# 7                6.1         True   False     False    TensorFlow
# 8                4.5         True   False      True  Scikit-learn
#
#    compensation
# 2         74321
# 3         62593
# 4         36288
# 5         61302
# 6         68984
# 7         18858
# 8         55418

# %%
df.iloc[2:6]
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
# 5                1.0         True   False     False       PyTorch
#
#    compensation
# 2         74321
# 3         62593
# 4         36288
# 5         61302

# %%
df.iloc[1:5,3]
# Out:
# 1     True
# 2    False
# 3     True
# 4    False
# Name: sql_user, dtype: bool

# %%
df.loc[2:6,'python_user']
# Out:
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# Name: python_user, dtype: bool

# %%
df1=pd.read_csv('compensation data.csv',index_col=1)   # Removes Column
df1
# Out:
#              experience_coding  r_user  sql_user     most_used  compensation
# python_user
# True                       6.1   False      True  Scikit-learn        124267
# True                      12.3    True      True  Scikit-learn        236889
# True                       2.2   False     False           NaN         74321
# False                      2.7   False      True           NaN         62593
# True                       1.2   False     False  Scikit-learn         36288
# ...                        ...     ...       ...           ...           ...
# True                       1.9   False      True  Scikit-learn         15800
# True                       1.4   False     False       PyTorch         62456
# False                      0.0   False     False           NaN           923
# True                       9.4   False      True  Scikit-learn         60609
# False                      0.0   False     False           NaN           493
#
# [25973 rows x 5 columns]

# %%
df1.loc['PyTorch']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:802, in pandas._libs.index.BoolEngine._check_type()
#
# KeyError: 'sql_user'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 df1.loc['sql_user']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
# ...

# %%
df1.loc['r_user',:'compensation']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:802, in pandas._libs.index.BoolEngine._check_type()
#
# KeyError: 'r_user'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[170], line 1
# ----> 1 df1.loc['r_user',:'compensation']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
# ...

# %%
df.iloc[8,5]  # row and column
# Out:
# 55418

# %%
df.iloc[[1,4]]  # List and shows required rows
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 1               12.3         True    True      True  Scikit-learn
# 4                1.2         True   False     False  Scikit-learn
#
#    compensation
# 1        236889
# 4         36288

# %%
df.iloc[[1,2]],[[3,5]]
# Out:
# (   experience_coding  python_user  r_user  sql_user     most_used  \
#  1               12.3         True    True      True  Scikit-learn
#  2                2.2         True   False     False           NaN
#
#     compensation
#  1        236889
#  2         74321  ,
#  [[3, 5]])

# %%
df['r_user']
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 25968    False
# 25969    False
# 25970    False
# 25971    False
# 25972    False
# Name: r_user, Length: 25973, dtype: bool

# %%
df[['experience_coding','r_user','compensation']]
# Out:
#        experience_coding  r_user  compensation
# 0                    6.1   False        124267
# 1                   12.3    True        236889
# 2                    2.2   False         74321
# 3                    2.7   False         62593
# 4                    1.2   False         36288
# ...                  ...     ...           ...
# 25968                1.9   False         15800
# 25969                1.4   False         62456
# 25970                0.0   False           923
# 25971                9.4   False         60609
# 25972                0.0   False           493
#
# [25973 rows x 3 columns]

# %%
df[['experience_coding','r_user','compensation']].head(3)
# Out:
#    experience_coding  r_user  compensation
# 0                6.1   False        124267
# 1               12.3    True        236889
# 2                2.2   False         74321

# %%
df.drop('most_used',axis=1)
# Out:
#        experience_coding  python_user  r_user  sql_user  compensation
# 0                    6.1         True   False      True        124267
# 1                   12.3         True    True      True        236889
# 2                    2.2         True   False     False         74321
# 3                    2.7        False   False      True         62593
# 4                    1.2         True   False     False         36288
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True         15800
# 25969                1.4         True   False     False         62456
# 25970                0.0        False   False     False           923
# 25971                9.4         True   False      True         60609
# 25972                0.0        False   False     False           493
#
# [25973 rows x 5 columns]

# %%
df.drop('most_used',axis=1,inplace = True)  # Removes a desired column

# %%
df
# Out:
#        experience_coding  python_user  r_user  sql_user  compensation
# 0                    6.1         True   False      True        124267
# 1                   12.3         True    True      True        236889
# 2                    2.2         True   False     False         74321
# 3                    2.7        False   False      True         62593
# 4                    1.2         True   False     False         36288
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True         15800
# 25969                1.4         True   False     False         62456
# 25970                0.0        False   False     False           923
# 25971                9.4         True   False      True         60609
# 25972                0.0        False   False     False           493
#
# [25973 rows x 5 columns]

# %%
df.drop(25970,inplace = True)   # Removes a row

# %%
df
# Out:
#        experience_coding  python_user  r_user  sql_user  compensation
# 0                    6.1         True   False      True        124267
# 1                   12.3         True    True      True        236889
# 2                    2.2         True   False     False         74321
# 3                    2.7        False   False      True         62593
# 4                    1.2         True   False     False         36288
# ...                  ...          ...     ...       ...           ...
# 25967                6.1         True   False      True         80090
# 25968                1.9         True   False      True         15800
# 25969                1.4         True   False     False         62456
# 25971                9.4         True   False      True         60609
# 25972                0.0        False   False     False           493
#
# [25972 rows x 5 columns]

# %%
df2=pd.read_csv('compensation data.csv', header=0)
df2
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df3=pd.read_csv('compensation data.csv', header=1)
df3
# Out:
#         6.1   TRUE  FALSE  TRUE.1  Scikit-learn  124267
# 0      12.3   True   True    True  Scikit-learn  236889
# 1       2.2   True  False   False           NaN   74321
# 2       2.7  False  False    True           NaN   62593
# 3       1.2   True  False   False  Scikit-learn   36288
# 4       1.0   True  False   False       PyTorch   61302
# ...     ...    ...    ...     ...           ...     ...
# 25967   1.9   True  False    True  Scikit-learn   15800
# 25968   1.4   True  False   False       PyTorch   62456
# 25969   0.0  False  False   False           NaN     923
# 25970   9.4   True  False    True  Scikit-learn   60609
# 25971   0.0  False  False   False           NaN     493
#
# [25972 rows x 6 columns]

# %% [markdown]
# # Logical Operators:

# %%
df['sql_user'] == 'TensorFlow'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25967    False
# 25968    False
# 25969    False
# 25971    False
# 25972    False
# Name: sql_user, Length: 25972, dtype: bool

# %%
df['sql_user'].unique()
# Out:
# array([ True, False])

# %%
df[(df['sql_user']=='Tensorflow')]
# Out:
# Empty DataFrame
# Columns: [experience_coding, python_user, r_user, sql_user, compensation]
# Index: []

# %%
df[(df['sql_user'] == 'TensorFlow') & (df['r_user'] == 'PyTorch')]
# Out:
# Empty DataFrame
# Columns: [experience_coding, python_user, r_user, sql_user, compensation]
# Index: []

# %%
df[(df['python_user'] == 'TensorFlow')& ~ (df['r_user'] == "PyTorch")]
# Out:
# Empty DataFrame
# Columns: [experience_coding, python_user, r_user, sql_user, compensation]
# Index: []

# %%
df[(df['sql_user'] == 'TensorFlow')| ~ (df['r_user'] == "PyTorch")]
# Out:
#        experience_coding  python_user  r_user  sql_user  compensation
# 0                    6.1         True   False      True        124267
# 1                   12.3         True    True      True        236889
# 2                    2.2         True   False     False         74321
# 3                    2.7        False   False      True         62593
# 4                    1.2         True   False     False         36288
# ...                  ...          ...     ...       ...           ...
# 25967                6.1         True   False      True         80090
# 25968                1.9         True   False      True         15800
# 25969                1.4         True   False     False         62456
# 25971                9.4         True   False      True         60609
# 25972                0.0        False   False     False           493
#
# [25972 rows x 5 columns]

# %%
df = pd.DataFrame([[1,2],[3,4],[7,9]],
                    index=['Cobra','clock','vipers'],
                     columns=['max_speed','sandwatch',])
df
# Out:
#         max_speed  sandwatch
# Cobra           1          2
# clock           3          4
# vipers          7          9
